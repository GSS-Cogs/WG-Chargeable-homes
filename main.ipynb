# %%
from gssutils import *
from requests import Session
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import ExpiresAfter

scraper = Scraper('https://statswales.gov.wales/Catalogue/Local-Government/Finance/Council-Tax/Dwellings/chargeableemptyandsecondhomesbylocalauthority',
                  session=CacheControl(Session(),
                                       cache=FileCache('.cache'),
                                       heuristic=ExpiresAfter(days=7)))
scraper
# Out:
# WARNING:http://open.statswales.gov.wales/en-gb/discover/metadata?$filter=Dataset eq 'lgfs0001' does not look like a valid URI, trying to serialize this will break.
# WARNING:http://open.statswales.gov.wales/en-gb/discover/datasetdimensions?$filter=Dataset eq 'lgfs0001' does not look like a valid URI, trying to serialize this will break.
# WARNING:http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset eq 'lgfs0001' does not look like a valid URI, trying to serialize this will break.
# ## Council tax dwellings
#
# The Welsh Government conducts the council tax dwellings survey (CT1 form). Data are available on the number of dwellings eligible for the council tax in each local authority for the next financial year, analysed by council tax band, including the numbers of properties eligible for council tax discounts and exemptions.Data cover Wales for all years since 1996-97. Data for earlier years is available from the Knowledge and Analytical Services division of the Welsh Government for the former districts of Wales, which were re-organised on 1 April 1996. The survey has been conducted every October to December since 1993-94. Results are available in early January, approximately three months before the beginning of the reference financial year.
#
# ### Distributions
#
# 1. Items ([application/json](http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset eq 'lgfs0001'))
# 1. Metadata ([application/json](http://open.statswales.gov.wales/en-gb/discover/metadata?$filter=Dataset eq 'lgfs0001'))
# 1. Dataset ([application/json](http://open.statswales.gov.wales/dataset/lgfs0001))
# 1. Dimensions ([application/json](http://open.statswales.gov.wales/en-gb/discover/datasetdimensions?$filter=Dataset eq 'lgfs0001'))

# %%
if len(scraper.distributions) == 0:
    from gssutils.metadata import Distribution
    dist = Distribution(scraper)
    dist.title = 'Dataset'
    dist.downloadURL = 'http://open.statswales.gov.wales/dataset/LGFS0001'
    dist.mediaType = 'application/json'
    scraper.distributions.append(dist)
table = scraper.distribution(title='Dataset').as_pandas()
table
# Out:
#       Authority_AltCode1  Authority_Code  Authority_Hierarchy  \
# 0              W06000001             512                  596
# 1              W06000001             512                  596
# 2              W06000001             512                  596
# 3              W06000001             512                  596
# 4              W06000001             512                  596
# 5              W06000001             512                  596
# 6              W06000001             512                  596
# 7              W06000001             512                  596
# 8              W06000001             512                  596
# 9              W06000001             512                  596
# 10             W06000001             512                  596
# 11             W06000001             512                  596
# 12             W06000001             512                  596
# 13             W06000001             512                  596
# 14             W06000001             512                  596
# 15             W06000001             512                  596
# 16             W06000001             512                  596
# 17             W06000001             512                  596
# 18             W06000001             512                  596
# 19             W06000001             512                  596
# 20             W06000001             512                  596
# 21             W06000001             512                  596
# 22             W06000001             512                  596
# 23             W06000001             512                  596
# 24             W06000001             512                  596
# 25             W06000001             512                  596
# 26             W06000001             512                  596
# 27             W06000001             512                  596
# 28             W06000001             512                  596
# 29             W06000001             512                  596
# ...                  ...             ...                  ...
# 92460          W92000004             596                  600
# 92461          W92000004             596                  600
# 92462          W92000004             596                  600
# 92463          W92000004             596                  600
# 92464          W92000004             596                  600
# 92465          W92000004             596                  600
# 92466          W92000004             596                  600
# 92467          W92000004             596                  600
# 92468          W92000004             596                  600
# 92469          W92000004             596                  600
# 92470          W92000004             596                  600
# 92471          W92000004             596                  600
# 92472          W92000004             596                  600
# 92473          W92000004             596                  600
# 92474          W92000004             596                  600
# 92475          W92000004             596                  600
# 92476          W92000004             596                  600
# 92477          W92000004             596                  600
# 92478          W92000004             596                  600
# 92479          W92000004             596                  600
# 92480          W92000004             596                  600
# 92481          W92000004             596                  600
# 92482          W92000004             596                  600
# 92483          W92000004             596                  600
# 92484          W92000004             596                  600
# 92485          W92000004             596                  600
# 92486          W92000004             596                  600
# 92487          W92000004             596                  600
# 92488          W92000004             596                  600
# 92489          W92000004             596                  600
#
#           Authority_ItemName_ENG  Authority_SortOrder  Band_Code  \
# 0               Isle of Anglesey                    1          1
# 1               Isle of Anglesey                    1          1
# 2               Isle of Anglesey                    1          1
# 3               Isle of Anglesey                    1          1
# 4               Isle of Anglesey                    1          1
# 5               Isle of Anglesey                    1          1
# 6               Isle of Anglesey                    1          1
# 7               Isle of Anglesey                    1          1
# 8               Isle of Anglesey                    1          1
# 9               Isle of Anglesey                    1          1
# 10              Isle of Anglesey                    1          1
# 11              Isle of Anglesey                    1          1
# 12              Isle of Anglesey                    1          1
# 13              Isle of Anglesey                    1          1
# 14              Isle of Anglesey                    1          1
# 15              Isle of Anglesey                    1          1
# 16              Isle of Anglesey                    1          1
# 17              Isle of Anglesey                    1          1
# 18              Isle of Anglesey                    1          1
# 19              Isle of Anglesey                    1          1
# 20              Isle of Anglesey                    1          1
# 21              Isle of Anglesey                    1          1
# 22              Isle of Anglesey                    1          1
# 23              Isle of Anglesey                    1          1
# 24              Isle of Anglesey                    1          1
# 25              Isle of Anglesey                    1          1
# 26              Isle of Anglesey                    1          1
# 27              Isle of Anglesey                    1          1
# 28              Isle of Anglesey                    1          1
# 29              Isle of Anglesey                    1          1
# ...                          ...                  ...        ...
# 92460  Total Unitary Authorities                   23         11
# 92461  Total Unitary Authorities                   23         11
# 92462  Total Unitary Authorities                   23         11
# 92463  Total Unitary Authorities                   23         11
# 92464  Total Unitary Authorities                   23         11
# 92465  Total Unitary Authorities                   23         11
# 92466  Total Unitary Authorities                   23         11
# 92467  Total Unitary Authorities                   23         11
# 92468  Total Unitary Authorities                   23         11
# 92469  Total Unitary Authorities                   23         11
# 92470  Total Unitary Authorities                   23         11
# 92471  Total Unitary Authorities                   23         11
# 92472  Total Unitary Authorities                   23         11
# 92473  Total Unitary Authorities                   23         11
# 92474  Total Unitary Authorities                   23         11
# 92475  Total Unitary Authorities                   23         11
# 92476  Total Unitary Authorities                   23         11
# 92477  Total Unitary Authorities                   23         11
# 92478  Total Unitary Authorities                   23         11
# 92479  Total Unitary Authorities                   23         11
# 92480  Total Unitary Authorities                   23         11
# 92481  Total Unitary Authorities                   23         11
# 92482  Total Unitary Authorities                   23         11
# 92483  Total Unitary Authorities                   23         11
# 92484  Total Unitary Authorities                   23         11
# 92485  Total Unitary Authorities                   23         11
# 92486  Total Unitary Authorities                   23         11
# 92487  Total Unitary Authorities                   23         11
# 92488  Total Unitary Authorities                   23         11
# 92489  Total Unitary Authorities                   23         11
#
#        Band_Hierarchy Band_ItemName_ENG  Band_SortOrder         Data  \
# 0                  11                A-               1        0.000
# 1                  11                A-               1        0.000
# 2                  11                A-               1        0.000
# 3                  11                A-               1        0.000
# 4                  11                A-               1        0.000
# 5                  11                A-               1        0.000
# 6                  11                A-               1        0.000
# 7                  11                A-               1        3.890
# 8                  11                A-               1        4.000
# 9                  11                A-               1        4.580
# 10                 11                A-               1        5.000
# 11                 11                A-               1        6.000
# 12                 11                A-               1        6.000
# 13                 11                A-               1        6.000
# 14                 11                A-               1        6.670
# 15                 11                A-               1        7.000
# 16                 11                A-               1        7.000
# 17                 11                A-               1        7.920
# 18                 11                A-               1        8.000
# 19                 11                A-               1        8.000
# 20                 11                A-               1        8.060
# 21                 11                A-               1        8.330
# 22                 11                A-               1        8.750
# 23                 11                A-               1        9.000
# 24                 11                A-               1        9.000
# 25                 11                A-               1       10.000
# 26                 11                A-               1       10.000
# 27                 11                A-               1       11.250
# 28                 11                A-               1       13.000
# 29                 11                A-               1       14.000
# ...               ...               ...             ...          ...
# 92460               0             Total              11  1146239.000
# 92461               0             Total              11  1155149.370
# 92462               0             Total              11  1157948.740
# 92463               0             Total              11  1173333.180
# 92464               0             Total              11  1177333.550
# 92465               0             Total              11  1190642.660
# 92466               0             Total              11  1196426.650
# 92467               0             Total              11  1201230.950
# 92468               0             Total              11  1206276.000
# 92469               0             Total              11  1209577.000
# 92470               0             Total              11  1214446.000
# 92471               0             Total              11  1221913.000
# 92472               0             Total              11  1228694.770
# 92473               0             Total              11  1233371.010
# 92474               0             Total              11  1234784.000
# 92475               0             Total              11  1245932.980
# 92476               0             Total              11  1253126.100
# 92477               0             Total              11  1275016.600
# 92478               0             Total              11  1279493.820
# 92479               0             Total              11  1308620.130
# 92480               0             Total              11  1312824.640
# 92481               0             Total              11  1327012.340
# 92482               0             Total              11  1338304.360
# 92483               0             Total              11  1343031.332
# 92484               0             Total              11  1350942.946
# 92485               0             Total              11  1358979.960
# 92486               0             Total              11  1369945.756
# 92487               0             Total              11  1375172.266
# 92488               0             Total              11  1375172.436
# 92489               0             Total              11  1380570.771
#
#       PartitionKey  RowKey Row_Code  \
# 0                        0      B2b
# 1                        1       B3
# 2                        2      B3a
# 3                        3      B3a
# 4                        4      B3a
# 5                        5       B5
# 6                        6       B5
# 7                        7       C4
# 8                        8       B1
# 9                        9       C4
# 10                      10       B2
# 11                      11       B1
# 12                      12       B2
# 13                      13       B2
# 14                      14       C4
# 15                      15       B2
# 16                      16       C2
# 17                      17       C4
# 18                      18       B2
# 19                      19       B4
# 20                      20       C4
# 21                      21       C4
# 22                      22       C2
# 23                      23       A3
# 24                      24       B4
# 25                      25       B1
# 26                      26       B4
# 27                      27       C2
# 28                      28       C5
# 29                      29       B4
# ...            ...     ...      ...
# 92460                92460       E6
# 92461                92461       E3
# 92462                92462       E6
# 92463                92463       E5
# 92464                92464       C4
# 92465                92465       E1
# 92466                92466       E1
# 92467                92467       E1
# 92468                92468       A1
# 92469                92469       C4
# 92470                92470       A1
# 92471                92471       B4
# 92472                92472       E6
# 92473                92473       E6
# 92474                92474       B4
# 92475                92475       A3
# 92476                92476       B4
# 92477                92477       B4
# 92478                92478       A1
# 92479                92479       A1
# 92480                92480       A1
# 92481                92481       A1
# 92482                92482       A1
# 92483                92483       A1
# 92484                92484       A1
# 92485                92485       B4
# 92486                92486       B4
# 92487                92487       A1
# 92488                92488       B4
# 92489                92489       B4
#
#                                         Row_ItemName_ENG  \
# 0      B2b - Dwellings with a 50% discount (excluding...
# 1                  B3 - Dwellings with a discount of 50%
# 2      B3a - Dwellings with a discount other than 25%...
# 3      B3a - Dwellings with a discount other than 25%...
# 4      B3a - Dwellings with a discount other than 25%...
# 5                          B5 - Total variable discounts
# 6                          B5 - Total variable discounts
# 7      C4 - Total discounted band D equivalent dwellings
# 8                       B1 - Dwellings with no discounts
# 9      C4 - Total discounted band D equivalent dwellings
# 10                 B2 - Dwellings with a discount of 25%
# 11                      B1 - Dwellings with no discounts
# 12                 B2 - Dwellings with a discount of 25%
# 13                 B2 - Dwellings with a discount of 25%
# 14     C4 - Total discounted band D equivalent dwellings
# 15                 B2 - Dwellings with a discount of 25%
# 16                       C2 - Total discounted dwellings
# 17     C4 - Total discounted band D equivalent dwellings
# 18                 B2 - Dwellings with a discount of 25%
# 19              B4 - Total adjusted chargeable dwellings
# 20     C4 - Total discounted band D equivalent dwellings
# 21     C4 - Total discounted band D equivalent dwellings
# 22                       C2 - Total discounted dwellings
# 23                    A3 - Adjusted chargeable dwellings
# 24              B4 - Total adjusted chargeable dwellings
# 25                      B1 - Dwellings with no discounts
# 26              B4 - Total adjusted chargeable dwellings
# 27                       C2 - Total discounted dwellings
# 28     C5 - Total discounted dwellings excluding prem...
# 29              B4 - Total adjusted chargeable dwellings
# ...                                                  ...
# 92460              E6 - Council taxbase for RSG purposes
# 92461                                        E3 - E1x E2
# 92462              E6 - Council taxbase for RSG purposes
# 92463                           E5 - Tax setting taxbase
# 92464  C4 - Total discounted band D equivalent dwellings
# 92465             E1 - Total band D equivalent dwellings
# 92466             E1 - Total band D equivalent dwellings
# 92467             E1 - Total band D equivalent dwellings
# 92468                      A1 - All chargeable dwellings
# 92469  C4 - Total discounted band D equivalent dwellings
# 92470                      A1 - All chargeable dwellings
# 92471           B4 - Total adjusted chargeable dwellings
# 92472              E6 - Council taxbase for RSG purposes
# 92473              E6 - Council taxbase for RSG purposes
# 92474           B4 - Total adjusted chargeable dwellings
# 92475                 A3 - Adjusted chargeable dwellings
# 92476           B4 - Total adjusted chargeable dwellings
# 92477           B4 - Total adjusted chargeable dwellings
# 92478                      A1 - All chargeable dwellings
# 92479                      A1 - All chargeable dwellings
# 92480                      A1 - All chargeable dwellings
# 92481                      A1 - All chargeable dwellings
# 92482                      A1 - All chargeable dwellings
# 92483                      A1 - All chargeable dwellings
# 92484                      A1 - All chargeable dwellings
# 92485           B4 - Total adjusted chargeable dwellings
# 92486           B4 - Total adjusted chargeable dwellings
# 92487                      A1 - All chargeable dwellings
# 92488           B4 - Total adjusted chargeable dwellings
# 92489           B4 - Total adjusted chargeable dwellings
#
#                                        Row_ItemNotes_ENG  Row_SortOrder  \
# 0                                                                     6
# 1      Dwellings subject to a discount equal to twice...              8
# 2      The number of dwellings receiving discounts ot...              9
# 3      The number of dwellings receiving discounts ot...              9
# 4      The number of dwellings receiving discounts ot...              9
# 5          The total number of variable discounts given.             13
# 6          The total number of variable discounts given.             13
# 7      The total discounted band D equivalent dwellin...             18
# 8      The number of dwellings receiving no discounts...              4
# 9      The total discounted band D equivalent dwellin...             18
# 10     The number of dwellings receiving one discount...              7
# 11     The number of dwellings receiving no discounts...              4
# 12     The number of dwellings receiving one discount...              7
# 13     The number of dwellings receiving one discount...              7
# 14     The total discounted band D equivalent dwellin...             18
# 15     The number of dwellings receiving one discount...              7
# 16     The total discounted dwellings is calculated b...             16
# 17     The total discounted band D equivalent dwellin...             18
# 18     The number of dwellings receiving one discount...              7
# 19     Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 20     The total discounted band D equivalent dwellin...             18
# 21     The total discounted band D equivalent dwellin...             18
# 22     The total discounted dwellings is calculated b...             16
# 23     A dwelling in bands B to H which is subject to...              3
# 24     Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 25     The number of dwellings receiving no discounts...              4
# 26     Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 27     The total discounted dwellings is calculated b...             16
# 28                                                                   19
# 29     Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# ...                                                  ...            ...
# 92460  100% council tax base for calculating revenue ...             35
# 92461  Discounted chargeable dwellings: band D equiva...             31
# 92462  100% council tax base for calculating revenue ...             35
# 92463   Council tax base for tax-setting purposes (=E3).             33
# 92464  The total discounted band D equivalent dwellin...             18
# 92465  Total discounted chargeable dwellings: band D ...             29
# 92466  Total discounted chargeable dwellings: band D ...             29
# 92467  Total discounted chargeable dwellings: band D ...             29
# 92468  This is not the number of dwellings in each ba...              1
# 92469  The total discounted band D equivalent dwellin...             18
# 92470  This is not the number of dwellings in each ba...              1
# 92471  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92472  100% council tax base for calculating revenue ...             35
# 92473  100% council tax base for calculating revenue ...             35
# 92474  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92475  A dwelling in bands B to H which is subject to...              3
# 92476  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92477  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92478  This is not the number of dwellings in each ba...              1
# 92479  This is not the number of dwellings in each ba...              1
# 92480  This is not the number of dwellings in each ba...              1
# 92481  This is not the number of dwellings in each ba...              1
# 92482  This is not the number of dwellings in each ba...              1
# 92483  This is not the number of dwellings in each ba...              1
# 92484  This is not the number of dwellings in each ba...              1
# 92485  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92486  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92487  This is not the number of dwellings in each ba...              1
# 92488  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
# 92489  Total adjusted chargeable dwellings (B1ݯ=A3). ...             12
#
#        Year_Code Year_ItemName_ENG  \
# 0         201819           2018-19
# 1         201213           2012-13
# 2         201112           2011-12
# 3         201617           2016-17
# 4         201819           2018-19
# 5         201213           2012-13
# 6         201920           2019-20
# 7         200708           2007-08
# 8         200708           2007-08
# 9         200910           2009-10
# 10        201011           2010-11
# 11        200405           2004-05
# 12        200102           2001-02
# 13        201213           2012-13
# 14        200203           2002-03
# 15        200304           2003-04
# 16        200708           2007-08
# 17        201920           2019-20
# 18        201516           2015-16
# 19        200708           2007-08
# 20        201314           2013-14
# 21        201516           2015-16
# 22        201011           2010-11
# 23        200506           2005-06
# 24        200506           2005-06
# 25        201617           2016-17
# 26        200910           2009-10
# 27        200405           2004-05
# 28        201819           2018-19
# 29        200203           2002-03
# ...          ...               ...
# 92460     200607           2006-07
# 92461     201112           2011-12
# 92462     200708           2007-08
# 92463     201415           2014-15
# 92464     201011           2010-11
# 92465     201213           2012-13
# 92466     201314           2013-14
# 92467     201415           2014-15
# 92468     199798           1997-98
# 92469     201516           2015-16
# 92470     199899           1998-99
# 92471     199900           1999-00
# 92472     201718           2017-18
# 92473     201819           2018-19
# 92474     200001           2000-01
# 92475     200102           2001-02
# 92476     200203           2002-03
# 92477     200405           2004-05
# 92478     200506           2005-06
# 92479     200809           2008-09
# 92480     200910           2009-10
# 92481     201112           2011-12
# 92482     201314           2013-14
# 92483     201415           2014-15
# 92484     201516           2015-16
# 92485     201617           2016-17
# 92486     201718           2017-18
# 92487     201819           2018-19
# 92488     201819           2018-19
# 92489     201920           2019-20
#
#                                       Year_ItemNotes_ENG  Year_SortOrder
# 0                                                                 201819
# 1                                                                 201213
# 2                                                                 201112
# 3                                                                 201617
# 4                                                                 201819
# 5                                                                 201213
# 6                                                                 201920
# 7                                                                 200708
# 8                                                                 200708
# 9                                                                 200910
# 10                                                                201011
# 11                                                                200405
# 12                                                                200102
# 13                                                                201213
# 14                                                                200203
# 15                                                                200304
# 16                                                                200708
# 17                                                                201920
# 18                                                                201516
# 19                                                                200708
# 20                                                                201314
# 21                                                                201516
# 22                                                                201011
# 23     In 2005-06 the council tax bands in Wales were...          200506
# 24     In 2005-06 the council tax bands in Wales were...          200506
# 25                                                                201617
# 26                                                                200910
# 27                                                                200405
# 28                                                                201819
# 29                                                                200203
# ...                                                  ...             ...
# 92460                                                             200607
# 92461                                                             201112
# 92462                                                             200708
# 92463                                                             201415
# 92464                                                             201011
# 92465                                                             201213
# 92466                                                             201314
# 92467                                                             201415
# 92468                                                             199798
# 92469                                                             201516
# 92470                                                             199899
# 92471                                                             199900
# 92472                                                             201718
# 92473                                                             201819
# 92474                                                             200001
# 92475                                                             200102
# 92476                                                             200203
# 92477                                                             200405
# 92478  In 2005-06 the council tax bands in Wales were...          200506
# 92479                                                             200809
# 92480                                                             200910
# 92481                                                             201112
# 92482                                                             201314
# 92483                                                             201415
# 92484                                                             201516
# 92485                                                             201617
# 92486                                                             201718
# 92487                                                             201819
# 92488                                                             201819
# 92489                                                             201920
#
# [92490 rows x 20 columns]

# %%
table.columns
# Out:
# Index(['Authority_AltCode1', 'Authority_Code', 'Authority_Hierarchy',
#        'Authority_ItemName_ENG', 'Authority_SortOrder', 'Band_Code',
#        'Band_Hierarchy', 'Band_ItemName_ENG', 'Band_SortOrder', 'Data',
#        'PartitionKey', 'RowKey', 'Row_Code', 'Row_ItemName_ENG',
#        'Row_ItemNotes_ENG', 'Row_SortOrder', 'Year_Code', 'Year_ItemName_ENG',
#        'Year_ItemNotes_ENG', 'Year_SortOrder'],
#       dtype='object')

# %%
cols = {
    'Authority_AltCode1': 'Geography',
    'Data': 'Value',
    'Row_Code': 'Chargeable homes',
    'Year_Code': 'Period'
}
to_remove = set(table.columns) - set(cols.keys())
table.rename(columns=cols, inplace=True)
table.drop(columns=to_remove, inplace=True)
table
# Out:
#        Geography        Value Chargeable homes  Period
# 0      W06000001        0.000              B2b  201819
# 1      W06000001        0.000               B3  201213
# 2      W06000001        0.000              B3a  201112
# 3      W06000001        0.000              B3a  201617
# 4      W06000001        0.000              B3a  201819
# 5      W06000001        0.000               B5  201213
# 6      W06000001        0.000               B5  201920
# 7      W06000001        3.890               C4  200708
# 8      W06000001        4.000               B1  200708
# 9      W06000001        4.580               C4  200910
# 10     W06000001        5.000               B2  201011
# 11     W06000001        6.000               B1  200405
# 12     W06000001        6.000               B2  200102
# 13     W06000001        6.000               B2  201213
# 14     W06000001        6.670               C4  200203
# 15     W06000001        7.000               B2  200304
# 16     W06000001        7.000               C2  200708
# 17     W06000001        7.920               C4  201920
# 18     W06000001        8.000               B2  201516
# 19     W06000001        8.000               B4  200708
# 20     W06000001        8.060               C4  201314
# 21     W06000001        8.330               C4  201516
# 22     W06000001        8.750               C2  201011
# 23     W06000001        9.000               A3  200506
# 24     W06000001        9.000               B4  200506
# 25     W06000001       10.000               B1  201617
# 26     W06000001       10.000               B4  200910
# 27     W06000001       11.250               C2  200405
# 28     W06000001       13.000               C5  201819
# 29     W06000001       14.000               B4  200203
# ...          ...          ...              ...     ...
# 92460  W92000004  1146239.000               E6  200607
# 92461  W92000004  1155149.370               E3  201112
# 92462  W92000004  1157948.740               E6  200708
# 92463  W92000004  1173333.180               E5  201415
# 92464  W92000004  1177333.550               C4  201011
# 92465  W92000004  1190642.660               E1  201213
# 92466  W92000004  1196426.650               E1  201314
# 92467  W92000004  1201230.950               E1  201415
# 92468  W92000004  1206276.000               A1  199798
# 92469  W92000004  1209577.000               C4  201516
# 92470  W92000004  1214446.000               A1  199899
# 92471  W92000004  1221913.000               B4  199900
# 92472  W92000004  1228694.770               E6  201718
# 92473  W92000004  1233371.010               E6  201819
# 92474  W92000004  1234784.000               B4  200001
# 92475  W92000004  1245932.980               A3  200102
# 92476  W92000004  1253126.100               B4  200203
# 92477  W92000004  1275016.600               B4  200405
# 92478  W92000004  1279493.820               A1  200506
# 92479  W92000004  1308620.130               A1  200809
# 92480  W92000004  1312824.640               A1  200910
# 92481  W92000004  1327012.340               A1  201112
# 92482  W92000004  1338304.360               A1  201314
# 92483  W92000004  1343031.332               A1  201415
# 92484  W92000004  1350942.946               A1  201516
# 92485  W92000004  1358979.960               B4  201617
# 92486  W92000004  1369945.756               B4  201718
# 92487  W92000004  1375172.266               A1  201819
# 92488  W92000004  1375172.436               B4  201819
# 92489  W92000004  1380570.771               B4  201920
#
# [92490 rows x 4 columns]

# %%
table['Period'] = table['Period'].map(lambda x: f'gregorian-interval/{str(x)[:4]}-03-31T00:00:00/P1Y')
table['Measure Type'] = 'Count'
table['Unit'] = 'vacancies'

# %%
out = Path('out')
out.mkdir(exist_ok=True, parents=True)
table.drop_duplicates().to_csv(out / 'observations.csv', index = False)

# %%
schema = CSVWSchema('https://ons-opendata.github.io/ref_housing/')
schema.create(out / 'observations.csv', out / 'observations.csv-schema.json')
# Out:
# "Chargeable homes" not defined

# %%
from datetime import datetime
scraper.dataset.family = 'housing'
scraper.dataset.theme = THEME['housing-planning-local-services']
scraper.dataset.modified = datetime.now()
scraper.dataset.creator = scraper.dataset.publisher
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())

# %%
table
# Out:
#        Geography        Value Chargeable homes  \
# 0      W06000001        0.000              B2b
# 1      W06000001        0.000               B3
# 2      W06000001        0.000              B3a
# 3      W06000001        0.000              B3a
# 4      W06000001        0.000              B3a
# 5      W06000001        0.000               B5
# 6      W06000001        0.000               B5
# 7      W06000001        3.890               C4
# 8      W06000001        4.000               B1
# 9      W06000001        4.580               C4
# 10     W06000001        5.000               B2
# 11     W06000001        6.000               B1
# 12     W06000001        6.000               B2
# 13     W06000001        6.000               B2
# 14     W06000001        6.670               C4
# 15     W06000001        7.000               B2
# 16     W06000001        7.000               C2
# 17     W06000001        7.920               C4
# 18     W06000001        8.000               B2
# 19     W06000001        8.000               B4
# 20     W06000001        8.060               C4
# 21     W06000001        8.330               C4
# 22     W06000001        8.750               C2
# 23     W06000001        9.000               A3
# 24     W06000001        9.000               B4
# 25     W06000001       10.000               B1
# 26     W06000001       10.000               B4
# 27     W06000001       11.250               C2
# 28     W06000001       13.000               C5
# 29     W06000001       14.000               B4
# ...          ...          ...              ...
# 92460  W92000004  1146239.000               E6
# 92461  W92000004  1155149.370               E3
# 92462  W92000004  1157948.740               E6
# 92463  W92000004  1173333.180               E5
# 92464  W92000004  1177333.550               C4
# 92465  W92000004  1190642.660               E1
# 92466  W92000004  1196426.650               E1
# 92467  W92000004  1201230.950               E1
# 92468  W92000004  1206276.000               A1
# 92469  W92000004  1209577.000               C4
# 92470  W92000004  1214446.000               A1
# 92471  W92000004  1221913.000               B4
# 92472  W92000004  1228694.770               E6
# 92473  W92000004  1233371.010               E6
# 92474  W92000004  1234784.000               B4
# 92475  W92000004  1245932.980               A3
# 92476  W92000004  1253126.100               B4
# 92477  W92000004  1275016.600               B4
# 92478  W92000004  1279493.820               A1
# 92479  W92000004  1308620.130               A1
# 92480  W92000004  1312824.640               A1
# 92481  W92000004  1327012.340               A1
# 92482  W92000004  1338304.360               A1
# 92483  W92000004  1343031.332               A1
# 92484  W92000004  1350942.946               A1
# 92485  W92000004  1358979.960               B4
# 92486  W92000004  1369945.756               B4
# 92487  W92000004  1375172.266               A1
# 92488  W92000004  1375172.436               B4
# 92489  W92000004  1380570.771               B4
#
#                                            Period Measure Type       Unit
# 0      gregorian-interval/2018-03-31T00:00:00/P1Y        Count  vacancies
# 1      gregorian-interval/2012-03-31T00:00:00/P1Y        Count  vacancies
# 2      gregorian-interval/2011-03-31T00:00:00/P1Y        Count  vacancies
# 3      gregorian-interval/2016-03-31T00:00:00/P1Y        Count  vacancies
# 4      gregorian-interval/2018-03-31T00:00:00/P1Y        Count  vacancies
# 5      gregorian-interval/2012-03-31T00:00:00/P1Y        Count  vacancies
# 6      gregorian-interval/2019-03-31T00:00:00/P1Y        Count  vacancies
# 7      gregorian-interval/2007-03-31T00:00:00/P1Y        Count  vacancies
# 8      gregorian-interval/2007-03-31T00:00:00/P1Y        Count  vacancies
# 9      gregorian-interval/2009-03-31T00:00:00/P1Y        Count  vacancies
# 10     gregorian-interval/2010-03-31T00:00:00/P1Y        Count  vacancies
# 11     gregorian-interval/2004-03-31T00:00:00/P1Y        Count  vacancies
# 12     gregorian-interval/2001-03-31T00:00:00/P1Y        Count  vacancies
# 13     gregorian-interval/2012-03-31T00:00:00/P1Y        Count  vacancies
# 14     gregorian-interval/2002-03-31T00:00:00/P1Y        Count  vacancies
# 15     gregorian-interval/2003-03-31T00:00:00/P1Y        Count  vacancies
# 16     gregorian-interval/2007-03-31T00:00:00/P1Y        Count  vacancies
# 17     gregorian-interval/2019-03-31T00:00:00/P1Y        Count  vacancies
# 18     gregorian-interval/2015-03-31T00:00:00/P1Y        Count  vacancies
# 19     gregorian-interval/2007-03-31T00:00:00/P1Y        Count  vacancies
# 20     gregorian-interval/2013-03-31T00:00:00/P1Y        Count  vacancies
# 21     gregorian-interval/2015-03-31T00:00:00/P1Y        Count  vacancies
# 22     gregorian-interval/2010-03-31T00:00:00/P1Y        Count  vacancies
# 23     gregorian-interval/2005-03-31T00:00:00/P1Y        Count  vacancies
# 24     gregorian-interval/2005-03-31T00:00:00/P1Y        Count  vacancies
# 25     gregorian-interval/2016-03-31T00:00:00/P1Y        Count  vacancies
# 26     gregorian-interval/2009-03-31T00:00:00/P1Y        Count  vacancies
# 27     gregorian-interval/2004-03-31T00:00:00/P1Y        Count  vacancies
# 28     gregorian-interval/2018-03-31T00:00:00/P1Y        Count  vacancies
# 29     gregorian-interval/2002-03-31T00:00:00/P1Y        Count  vacancies
# ...                                           ...          ...        ...
# 92460  gregorian-interval/2006-03-31T00:00:00/P1Y        Count  vacancies
# 92461  gregorian-interval/2011-03-31T00:00:00/P1Y        Count  vacancies
# 92462  gregorian-interval/2007-03-31T00:00:00/P1Y        Count  vacancies
# 92463  gregorian-interval/2014-03-31T00:00:00/P1Y        Count  vacancies
# 92464  gregorian-interval/2010-03-31T00:00:00/P1Y        Count  vacancies
# 92465  gregorian-interval/2012-03-31T00:00:00/P1Y        Count  vacancies
# 92466  gregorian-interval/2013-03-31T00:00:00/P1Y        Count  vacancies
# 92467  gregorian-interval/2014-03-31T00:00:00/P1Y        Count  vacancies
# 92468  gregorian-interval/1997-03-31T00:00:00/P1Y        Count  vacancies
# 92469  gregorian-interval/2015-03-31T00:00:00/P1Y        Count  vacancies
# 92470  gregorian-interval/1998-03-31T00:00:00/P1Y        Count  vacancies
# 92471  gregorian-interval/1999-03-31T00:00:00/P1Y        Count  vacancies
# 92472  gregorian-interval/2017-03-31T00:00:00/P1Y        Count  vacancies
# 92473  gregorian-interval/2018-03-31T00:00:00/P1Y        Count  vacancies
# 92474  gregorian-interval/2000-03-31T00:00:00/P1Y        Count  vacancies
# 92475  gregorian-interval/2001-03-31T00:00:00/P1Y        Count  vacancies
# 92476  gregorian-interval/2002-03-31T00:00:00/P1Y        Count  vacancies
# 92477  gregorian-interval/2004-03-31T00:00:00/P1Y        Count  vacancies
# 92478  gregorian-interval/2005-03-31T00:00:00/P1Y        Count  vacancies
# 92479  gregorian-interval/2008-03-31T00:00:00/P1Y        Count  vacancies
# 92480  gregorian-interval/2009-03-31T00:00:00/P1Y        Count  vacancies
# 92481  gregorian-interval/2011-03-31T00:00:00/P1Y        Count  vacancies
# 92482  gregorian-interval/2013-03-31T00:00:00/P1Y        Count  vacancies
# 92483  gregorian-interval/2014-03-31T00:00:00/P1Y        Count  vacancies
# 92484  gregorian-interval/2015-03-31T00:00:00/P1Y        Count  vacancies
# 92485  gregorian-interval/2016-03-31T00:00:00/P1Y        Count  vacancies
# 92486  gregorian-interval/2017-03-31T00:00:00/P1Y        Count  vacancies
# 92487  gregorian-interval/2018-03-31T00:00:00/P1Y        Count  vacancies
# 92488  gregorian-interval/2018-03-31T00:00:00/P1Y        Count  vacancies
# 92489  gregorian-interval/2019-03-31T00:00:00/P1Y        Count  vacancies
#
# [92490 rows x 6 columns]
